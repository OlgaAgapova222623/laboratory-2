# %% [markdown]
# # Pandas

# %% [markdown]
# Материалы:
# * Макрушин С.В. "Лекция 2: Библиотека Pandas"
# * https://pandas.pydata.org/docs/user_guide/index.html#
# * https://pandas.pydata.org/docs/reference/index.html
# * Уэс Маккини. Python и анализ данных

# %% [markdown]
# ## Задачи для совместного разбора

# %% [markdown]
# 1. Загрузите данные из файла `sp500hst.txt` и обозначьте столбцы в соответствии с содержимым: `"date", "ticker", "open", "high", "low", "close", "volume"`.

# %% [markdown]
# 2. Рассчитайте среднее значение показателей для каждого из столбцов c номерами 3-6.

# %% [markdown]
# 3. Добавьте столбец, содержащий только число месяца, к которому относится дата.

# %% [markdown]
# 4. Рассчитайте суммарный объем торгов для для одинаковых значений тикеров.

# %% [markdown]
# 5. Загрузите данные из файла sp500hst.txt и обозначьте столбцы в соответствии с содержимым: "date", "ticker", "open", "high", "low", "close", "volume". Добавьте столбец с расшифровкой названия тикера, используя данные из файла `sp_data2.csv` . В случае нехватки данных об именах тикеров корректно обработать их.

# %% [markdown]
# ## Лабораторная работа №2

# %% [markdown]
# ### Базовые операции с `DataFrame`

# %%
import numpy as np
import pandas as pd

# %%
pd.options.display.max_rows = 10

# %% [markdown]
# 1.1 В файлах `recipes_sample.csv` и `reviews_sample.csv` находится информация об рецептах блюд и отзывах на эти рецепты соответственно. Загрузите данные из файлов в виде `pd.DataFrame` с названиями `recipes` и `reviews`. Обратите внимание на корректное считывание столбца с индексами в таблице `reviews` (безымянный столбец).

# %%
recipes = pd.read_csv('02_pandas/sem/data/recipes_sample.csv', index_col = 'id')

# %%
recipes
# Out:
#                                                 name  minutes  contributor_id  \
# id
# 44123          george s at the cove  black bean soup       90           35193
# 67664             healthy for them  yogurt popsicles       10           91970
# 38798                   i can t believe it s spinach       30            1533
# 35173                           italian  gut busters       45           22724
# 84797       love is in the air  beef fondue   sauces       25            4470
# ...                                              ...      ...             ...
# 267661  zurie s holey rustic olive and cheddar bread       80          200862
# 386977          zwetschgenkuchen  bavarian plum cake      240          177443
# 103312   zwiebelkuchen   southwest german onion cake       75          161745
# 486161                                   zydeco soup       60          227978
# 298512        cookies by design   cookies on a stick       29          506822
#
# ...

# %%
reviews = pd.read_csv('02_pandas/sem/data/reviews_sample.csv', index_col = [0])

# %%
reviews
# Out:
#             user_id  recipe_id        date  rating  \
# 370476        21752      57993  2003-05-01       5
# 624300       431813     142201  2007-09-16       5
# 187037       400708     252013  2008-01-10       4
# 706134   2001852463     404716  2017-12-11       5
# 312179        95810     129396  2008-03-14       5
# ...             ...        ...         ...     ...
# 1013457     1270706     335534  2009-05-17       4
# 158736      2282344       8701  2012-06-03       0
# 1059834      689540     222001  2008-04-08       5
# 453285   2000242659     354979  2015-06-02       5
# 691207       463435     415599  2010-09-30       5
#
#                                                     review
# 370476   Last week whole sides of frozen salmon fillet ...
# 624300   So simple and so tasty!  I used a yellow capsi...
# 187037   Very nice breakfast HH, easy to make and yummy...
# 706134   These are a favorite for the holidays and so e...
# ...

# %% [markdown]
# 1.2 Для каждой из таблиц выведите основные параметры:
# * количество точек данных (строк);
# * количество столбцов;
# * тип данных каждого столбца.

# %%
print(recipes.shape)
print(recipes.dtypes)
print('==========================')
print(reviews.shape)
print(reviews.dtypes)
# Out:
# (30000, 7)
# name               object
# minutes             int64
# contributor_id      int64
# submitted          object
# n_steps           float64
# description        object
# n_ingredients     float64
# dtype: object
# ...
# (126696, 5)
# user_id       int64
# recipe_id     int64
# date         object
# rating        int64
# review       object
# dtype: object

# %% [markdown]
# 1.3 Исследуйте, в каких столбцах таблиц содержатся пропуски. Посчитайте долю строк, содержащих пропуски, в отношении к общему количеству строк.

# %%
recNan = recipes.isnull().sum().to_frame()
recNan
# Out:
#                     0
# name                0
# minutes             0
# contributor_id      0
# submitted           0
# n_steps         11190
# description       623
# n_ingredients    8880

# %%
recNan['a'] = recNan[0]/recipes.shape[0] * 100
recNan
# Out:
#                     0          a
# name                0   0.000000
# minutes             0   0.000000
# contributor_id      0   0.000000
# submitted           0   0.000000
# n_steps         11190  37.300000
# description       623   2.076667
# n_ingredients    8880  29.600000

# %%
revNan = reviews.isnull().sum().to_frame()
revNan
# Out:
#             0
# user_id     0
# recipe_id   0
# date        0
# rating      0
# review     17

# %%
revNan['a'] = revNan[0]/reviews.shape[0] * 100
revNan
# Out:
#             0         a
# user_id     0  0.000000
# recipe_id   0  0.000000
# date        0  0.000000
# rating      0  0.000000
# review     17  0.013418

# %% [markdown]
# 1.4 Рассчитайте среднее значение для каждого из числовых столбцов (где это имеет смысл).

# %%
print(recipes['minutes'].mean())
print(recipes['n_ingredients'].mean())
print(recipes['n_steps'].mean())
print(reviews['rating'].mean())
# Out:
# 123.35813333333333
# 9.008285984848484
# 9.805582137161085
# 4.410802235271832

# %% [markdown]
# 1.5 Создайте серию из 10 случайных названий рецептов.

# %%
recipes['name'].sample(10).to_frame()
# Out:
#                                                   name
# id
# 116542                      caramel chicken with herbs
# 63116                         pepper steak in a packet
# 281731                   mushroom quesadillas  healthy
# 99823        chocolate spoon cake with cognac cherries
# 279144  healthy  low fat breakfast sandwich  on the go
# 408262                        ham hocks and lima beans
# 340594       casbah chicken   couscous   pampered chef
# 293879          pizza escarole  escarole pie   italian
# 413711                         country ham cheese ball
# 16385                                   pasta dough  1

# %% [markdown]
# 1.6 Измените индекс в таблице `reviews`, пронумеровав строки, начиная с нуля.

# %%
reviews.reset_index()
# Out:
#           index     user_id  recipe_id        date  rating  \
# 0        370476       21752      57993  2003-05-01       5
# 1        624300      431813     142201  2007-09-16       5
# 2        187037      400708     252013  2008-01-10       4
# 3        706134  2001852463     404716  2017-12-11       5
# 4        312179       95810     129396  2008-03-14       5
# ...         ...         ...        ...         ...     ...
# 126691  1013457     1270706     335534  2009-05-17       4
# 126692   158736     2282344       8701  2012-06-03       0
# 126693  1059834      689540     222001  2008-04-08       5
# 126694   453285  2000242659     354979  2015-06-02       5
# 126695   691207      463435     415599  2010-09-30       5
#
#                                                    review
# 0       Last week whole sides of frozen salmon fillet ...
# 1       So simple and so tasty!  I used a yellow capsi...
# 2       Very nice breakfast HH, easy to make and yummy...
# ...

# %% [markdown]
# 1.7 Выведите информацию о рецептах, время выполнения которых не больше 20 минут и кол-во ингредиентов в которых не больше 5.

# %%
recipes[(recipes['minutes'] <= 20) & (recipes['n_ingredients'] <= 5)]
# Out:
#                                                      name  minutes  \
# id
# 302399                                quick biscuit bread       20
# 303944                      peas  fit for a king or queen       20
# 100837                  hawaiian sunrise           mimosa        5
# 286484         tasty dish s   banana pudding in 2 minutes        2
# 11361                                  1 minute meatballs       13
# ...                                                   ...      ...
# 304922  zip and steam red potatoes with butter and garlic       13
# 74250                           ziplock vanilla ice cream       10
# 256177                      zucchini and corn with cheese       15
# 320622               zucchini with jalapeno monterey jack       10
# 162411                          zucchini with serrano ham       15
#
#         contributor_id   submitted  n_steps  \
# id
# 302399          213909  2008-05-06     11.0
# 303944          213909  2008-05-16      NaN
# ...

# %% [markdown]
# ### Работа с датами в `pandas`

# %% [markdown]
# 2.1 Преобразуйте столбец `submitted` из таблицы `recipes` в формат времени. Модифицируйте решение задачи 1.1 так, чтобы считать столбец сразу в нужном формате.

# %%
recipesDT = pd.read_csv('02_pandas/sem/data/recipes_sample.csv', index_col = 'id', parse_dates = ['submitted'])

# %%
recipesDT.dtypes
# Out:
# name                      object
# minutes                    int64
# contributor_id             int64
# submitted         datetime64[ns]
# n_steps                  float64
# description               object
# n_ingredients            float64
# dtype: object

# %% [markdown]
# 2.2 Выведите информацию о рецептах, добавленных в датасет не позже 2010 года.

# %%
recipesDT[recipesDT['submitted'] <= '2010-01-01']
# Out:
#                                                      name  minutes  \
# id
# 44123               george s at the cove  black bean soup       90
# 67664                  healthy for them  yogurt popsicles       10
# 38798                        i can t believe it s spinach       30
# 35173                                italian  gut busters       45
# 84797            love is in the air  beef fondue   sauces       25
# 44045                            mennonite  corn fritters       15
# 107229                               open sesame  noodles       28
# 95926                          say what   banana sandwich        5
# 306168                             412 broccoli casserole       40
# 50662                                    25 000 casserole      125
# 118843                      250 00 chocolate chip cookies       20
# 69190                                   ara s potato  oup      135
# 149593                           add in anything  muffins       15
# ...

# %% [markdown]
# ### Работа со строковыми данными в `pandas`

# %% [markdown]
# 3.1  Добавьте в таблицу `recipes` столбец `description_length`, в котором хранится длина описания рецепта из столбца `description`.

# %%
recipes['description_length'] = recipes['description'].str.len()

# %%
recipes
# Out:
#                                                      name  minutes  \
# id
# 44123               george s at the cove  black bean soup       90
# 67664                  healthy for them  yogurt popsicles       10
# 38798                        i can t believe it s spinach       30
# 35173                                italian  gut busters       45
# 84797            love is in the air  beef fondue   sauces       25
# 44045                            mennonite  corn fritters       15
# 107229                               open sesame  noodles       28
# 95926                          say what   banana sandwich        5
# 453467                 1 in canada chocolate chip cookies       45
# 306168                             412 broccoli casserole       40
# 50662                                    25 000 casserole      125
# 118843                      250 00 chocolate chip cookies       20
# 69190                                   ara s potato  oup      135
# ...

# %% [markdown]
# 3.2 Измените название каждого рецепта в таблице `recipes` таким образом, чтобы каждое слово в названии начиналось с прописной буквы.

# %%
recipes['name'] = recipes['name'].str.capitalize()

# %%
recipes
# Out:
#                                                      name  minutes  \
# id
# 44123               George s at the cove  black bean soup       90
# 67664                  Healthy for them  yogurt popsicles       10
# 38798                        I can t believe it s spinach       30
# 35173                                Italian  gut busters       45
# 84797            Love is in the air  beef fondue   sauces       25
# 44045                            Mennonite  corn fritters       15
# 107229                               Open sesame  noodles       28
# 95926                          Say what   banana sandwich        5
# 453467                 1 in canada chocolate chip cookies       45
# 306168                             412 broccoli casserole       40
# 50662                                    25 000 casserole      125
# 118843                      250 00 chocolate chip cookies       20
# 69190                                   Ara s potato  oup      135
# ...

# %% [markdown]
# 3.3 Добавьте в таблицу `recipes` столбец `name_word_count`, в котором хранится количество слов из названии рецепта (считайте, что слова в названии разделяются только пробелами). Обратите внимание, что между словами может располагаться несколько пробелов подряд.

# %%
recipes['name_word_count'] = recipes['name'].str.split().str.len()

# %%
recipes
# Out:
#                                                      name  minutes  \
# id
# 44123               George s at the cove  black bean soup       90
# 67664                  Healthy for them  yogurt popsicles       10
# 38798                        I can t believe it s spinach       30
# 35173                                Italian  gut busters       45
# 84797            Love is in the air  beef fondue   sauces       25
# 44045                            Mennonite  corn fritters       15
# 107229                               Open sesame  noodles       28
# 95926                          Say what   banana sandwich        5
# 453467                 1 in canada chocolate chip cookies       45
# 306168                             412 broccoli casserole       40
# 50662                                    25 000 casserole      125
# 118843                      250 00 chocolate chip cookies       20
# 69190                                   Ara s potato  oup      135
# ...

# %% [markdown]
# ### Группировки таблиц `pd.DataFrame`

# %% [markdown]
# 4.1 Посчитайте количество рецептов, представленных каждым из участников (`contributor_id`). Какой участник добавил максимальное кол-во рецептов?

# %%
recipes.groupby('contributor_id')['name'].count().to_frame().sort_values(by = 'name', ascending = False)
# Out:
#                 name
# contributor_id
# 89831            421
# 37449            346
# 37779            345
# 1533             186
# 169430           183
# 58104            180
# 80353            147
# 4470             141
# 283251           127
# 166642           115
# 305531           113
# 27643            109
# 17803            108
# 424680           108
# 37636            105
# 383346           105
# 21752            100
# 5060              99
# 52282             98
# 39835             94
# 64642             93
# 23302             92
# 47892             91
# 68460             90
# 49304             90
# 133174            89
# 386585            89
# 53959             84
# 6357              84
# 24386             82
# ...              ...
# 242482             1
# 242413             1
# 242201             1
# 241872             1
# 241697             1
# 241696             1
# 245159             1
# 245247             1
# 245280             1
# 245367             1
# ...

# %% [markdown]
# 4.2 Посчитайте средний рейтинг к каждому из рецептов. Для скольких рецептов отсутствуют отзывы? Обратите внимание, что отзыв с нулевым рейтингом или не заполненным текстовым описанием не считается отсутствующим.

# %%
reviews.groupby('recipe_id')['rating'].mean()
# Out:
# recipe_id
# 48        1.000000
# 55        4.750000
# 66        4.944444
# 91        4.750000
# 94        5.000000
# 128       5.000000
# 148       0.000000
# 153       3.923077
# 176       5.000000
# 181       2.666667
# 186       4.777778
# 203       4.071429
# 224       3.000000
# 240       3.857143
# 246       4.629630
# 282       5.000000
# 284       5.000000
# 288       2.666667
# 289       5.000000
# 314       4.818182
# 318       4.750000
# 321       5.000000
# 337       2.000000
# 344       2.000000
# 352       3.750000
# 360       5.000000
# 373       5.000000
# 378       4.625000
# 379       4.666667
# 381       5.000000
#             ...
# 534062    0.000000
# 534064    5.000000
# 534196    0.000000
# 534283    5.000000
# 534393    0.000000
# 534549    4.000000
# 534786    5.000000
# 534855    5.000000
# 535104    5.000000
# 535120    5.000000
# 535269    0.000000
# 535312    0.000000
# 535389    5.000000
# 535555    4.500000
# 535584    0.000000
# 535650    5.000000
# ...

# %%
recipes.reset_index(inplace = True)

# %%
recipes['id'].isin(reviews['recipe_id']).value_counts()
# Out:
# True     28100
# False     1900
# Name: id, dtype: int64

# %% [markdown]
# 4.3 Посчитайте количество рецептов с разбивкой по годам создания.

# %%
recipesDT.groupby(recipesDT['submitted'].dt.year)['name'].count()
# Out:
# submitted
# 1999     275
# 2000     104
# 2001     589
# 2002    2644
# 2003    2334
# 2004    2153
# 2005    3130
# 2006    3473
# 2007    4429
# 2008    4029
# 2009    2963
# 2010    1538
# 2011     922
# 2012     659
# 2013     490
# 2014     139
# 2015      42
# 2016      24
# 2017      39
# 2018      24
# Name: name, dtype: int64

# %% [markdown]
# ### Объединение таблиц `pd.DataFrame`

# %% [markdown]
# 5.1 При помощи объединения таблиц, создайте `DataFrame`, состоящий из четырех столбцов: `id`, `name`, `user_id`, `rating`. Рецепты, на которые не оставлен ни один отзыв, должны отсутствовать в полученной таблице. Подтвердите правильность работы вашего кода, выбрав рецепт, не имеющий отзывов, и попытавшись найти строку, соответствующую этому рецепту, в полученном `DataFrame`.

# %%
recipes.reset_index()
# Out:
#            id                                          name  minutes  \
# 0       44123         george s at the cove  black bean soup       90
# 1       67664            healthy for them  yogurt popsicles       10
# 2       38798                  i can t believe it s spinach       30
# 3       35173                          italian  gut busters       45
# 4       84797      love is in the air  beef fondue   sauces       25
# ...       ...                                           ...      ...
# 29995  267661  zurie s holey rustic olive and cheddar bread       80
# 29996  386977          zwetschgenkuchen  bavarian plum cake      240
# 29997  103312   zwiebelkuchen   southwest german onion cake       75
# 29998  486161                                   zydeco soup       60
# 29999  298512        cookies by design   cookies on a stick       29
#
#        contributor_id   submitted  n_steps  \
# 0               35193  2002-10-25      NaN
# 1               91970  2003-07-26      NaN
# ...

# %%
rec_rev_1 = recipes.merge(reviews, 
                        how = 'inner', 
                        left_on='id', 
                        right_on='recipe_id')

# %%
rec_rev_1.columns
# Out:
# Index(['name', 'minutes', 'contributor_id', 'submitted', 'n_steps',
#        'description', 'n_ingredients', 'user_id', 'recipe_id', 'date',
#        'rating', 'review'],
#       dtype='object')

# %%
rec_rev_1 = rec_rev_1[['recipe_id','name','user_id','rating']]

# %%
rec_rev_1.rename(columns={'recipe_id':'id'})
# Out:
#             id                                    name  user_id  rating
# 0        44123   george s at the cove  black bean soup   743566       5
# 1        44123   george s at the cove  black bean soup    76503       5
# 2        44123   george s at the cove  black bean soup    34206       5
# 3        67664      healthy for them  yogurt popsicles   494084       5
# 4        67664      healthy for them  yogurt popsicles   303445       5
# ...        ...                                     ...      ...     ...
# 126691  486161                             zydeco soup   305531       5
# 126692  486161                             zydeco soup  1271506       5
# 126693  486161                             zydeco soup   724631       5
# 126694  486161                             zydeco soup   133174       5
# 126695  298512  cookies by design   cookies on a stick   804234       1
#
# [126696 rows x 4 columns]

# %% [markdown]
# 5.2 При помощи объединения таблиц и группировок, создайте `DataFrame`, состоящий из трех столбцов: `recipe_id`, `name`, `review_count`, где столбец `review_count` содержит кол-во отзывов, оставленных на рецепт `recipe_id`. У рецептов, на которые не оставлен ни один отзыв, в столбце `review_count` должен быть указан 0. Подтвердите правильность работы вашего кода, выбрав рецепт, не имеющий отзывов, и найдя строку, соответствующую этому рецепту, в полученном `DataFrame`.

# %%
rec_rev = recipes.merge(reviews, 
                        how = 'left', 
                        left_on='id', 
                        right_on='recipe_id')

# %%
rec_rev
# Out:
#                                           name  minutes  contributor_id  \
# 0        george s at the cove  black bean soup       90           35193
# 1        george s at the cove  black bean soup       90           35193
# 2        george s at the cove  black bean soup       90           35193
# 3           healthy for them  yogurt popsicles       10           91970
# 4           healthy for them  yogurt popsicles       10           91970
# ...                                        ...      ...             ...
# 128591                             zydeco soup       60          227978
# 128592                             zydeco soup       60          227978
# 128593                             zydeco soup       60          227978
# 128594                             zydeco soup       60          227978
# 128595  cookies by design   cookies on a stick       29          506822
#
#          submitted  n_steps  \
# 0       2002-10-25      NaN
# 1       2002-10-25      NaN
# ...

# %%
rec_rev.columns
# Out:
# Index(['name', 'minutes', 'contributor_id', 'submitted', 'n_steps',
#        'description', 'n_ingredients', 'user_id', 'recipe_id', 'date',
#        'rating', 'review'],
#       dtype='object')

# %%
rec_rev = rec_rev[['recipe_id','name','review']]

# %%
rec_rev.fillna(0).drop_duplicates()
# Out:
#         recipe_id                                    name  \
# 0         44123.0   george s at the cove  black bean soup
# 1         44123.0   george s at the cove  black bean soup
# 2         44123.0   george s at the cove  black bean soup
# 3         67664.0      healthy for them  yogurt popsicles
# 4         67664.0      healthy for them  yogurt popsicles
# ...           ...                                     ...
# 128591   486161.0                             zydeco soup
# 128592   486161.0                             zydeco soup
# 128593   486161.0                             zydeco soup
# 128594   486161.0                             zydeco soup
# 128595   298512.0  cookies by design   cookies on a stick
#
#                                                    review
# 0       I lived in San Diego for 19 years and  would g...
# 1       This soup is the Bomb! Don't hesitate to try.....
# 2       I just can't say enough about how wonderful th...
# ...

# %%
rec_rev.groupby(['recipe_id','name'])['review'].count().reset_index().sort_values(by=['review'], ascending=False).rename(columns={'review':'review_count'})
# Out:
#        recipe_id                                               name  \
# 1776     27208.0                         to die for crock pot roast
# 5812     82102.0  kittencal s moist cheddar garlic oven fried ch...
# 9695    135350.0    fannie farmer s classic baked macaroni   cheese
# 7751    107786.0      beth s melt in your mouth barbecue ribs  oven
# 3506     50719.0                     the sweetest blueberry muffins
# ...          ...                                                ...
# 19255   296171.0                              ranch chicken fajitas
# 11395   162060.0  eggplant  aubergine    crepes  with spinach fi...
# 19258   296231.0                              yum yum avocado salsa
# 19259   296234.0                        mini mascarpone cheesecakes
# 7068     98745.0                           my kids favorite goulash
#
#        review_count
# 1776           1382
# 5812            708
# 9695            674
# 7751            591
# 3506            486
# ...             ...
# ...

# %% [markdown]
# 5.2 При помощи объединения таблиц и группировок, создайте `DataFrame`, состоящий из трех столбцов: `recipe_id`, `name`, `review_count`, где столбец `review_count` содержит кол-во отзывов, оставленных на рецепт `recipe_id`. У рецептов, на которые не оставлен ни один отзыв, в столбце `review_count` должен быть указан 0. Подтвердите правильность работы вашего кода, выбрав рецепт, не имеющий отзывов, и найдя строку, соответствующую этому рецепту, в полученном `DataFrame`.

# %% [markdown]
# 5.3. Выясните, рецепты, добавленные в каком году, имеют наименьший средний рейтинг?

# %%
rec_rev_2 = recipesDT.merge(reviews, 
                        how = 'left', 
                        left_on='id', 
                        right_on='recipe_id')

# %%
rec_rev_2
# Out:
#                                           name  minutes  contributor_id  \
# 0        george s at the cove  black bean soup       90           35193
# 1        george s at the cove  black bean soup       90           35193
# 2        george s at the cove  black bean soup       90           35193
# 3           healthy for them  yogurt popsicles       10           91970
# 4           healthy for them  yogurt popsicles       10           91970
# ...                                        ...      ...             ...
# 128591                             zydeco soup       60          227978
# 128592                             zydeco soup       60          227978
# 128593                             zydeco soup       60          227978
# 128594                             zydeco soup       60          227978
# 128595  cookies by design   cookies on a stick       29          506822
#
#         submitted  n_steps                                        description  \
# ...

# %%
a = rec_rev_2.groupby(rec_rev_2['submitted'].dt.year)['rating'].mean().to_frame().reset_index().sort_values(by='rating')

# %%
a
# Out:
#     submitted    rating
# 18       2017  2.750000
# 19       2018  3.388889
# 17       2016  3.538462
# 16       2015  4.207317
# 0        1999  4.274895
# ..        ...       ...
# 7        2006  4.416310
# 8        2007  4.420073
# 4        2003  4.439152
# 5        2004  4.463778
# 15       2014  4.538235
#
# [20 rows x 2 columns]

# %%
a['submitted'].iloc[0]
# Out:
# 2017

# %% [markdown]
# ### Сохранение таблиц `pd.DataFrame`

# %% [markdown]
# 6.1 Отсортируйте таблицу в порядке убывания величины столбца `name_word_count` и сохраните результаты выполнения заданий 3.1-3.3 в csv файл.

# %%
a = recipes.sort_values(by='name_word_count')

# %% [markdown]
# 6.2 Воспользовавшись `pd.ExcelWriter`, cохраните результаты 5.1 и 5.2 в файл: на лист с названием `Рецепты с оценками` сохраните результаты выполнения 5.1; на лист с названием `Количество отзывов по рецептам` сохраните результаты выполнения 5.2.

# %% [markdown]
# #### [версия 2]
# * Уточнены формулировки задач 1.1, 3.3, 4.2, 5.1, 5.2, 5.3
